# %%
# dst = Image.new('RGB', (im1.width + im2.width, max(im1.height, im2.height)), color)
dst = Image.new(mode="RGB", size=(1400,1600), color="white")
imag1=Image.open(r'./images/1.jpg')
imag1 = imag1.resize((200, 150))

imag2=Image.open(r'./images/2.jpg')
imag2 = imag2.resize((200, 150))

# %%
plt.imshow(imag1)

# %%
dst.paste(imag1, (0, 150))
dst.paste(imag2, (200, 150))
dst.paste(imag1,(400,150))
dst.paste(imag2, (600, 150))
dst.paste(imag1, (800, 150))
dst.paste(imag2, (1000, 150))
dst.paste(imag1, (1200, 150))

# %%
dst.paste(imag1, (0, 400))
dst.paste(imag2, (200, 400))
dst.paste(imag1,(400,400))
dst.paste(imag2, (600, 400))
dst.paste(imag1, (800, 400))
dst.paste(imag2, (1000, 400))
dst.paste(imag1, (1200, 400))

# %%
big_image = imag1.resize((200, 400))

# %%
dst.paste(big_image, (1200, 1100))

# %%
dst.paste(imag2,(200,1100))
dst.paste(imag1,(400,1100))
dst.paste(imag2, (600, 1100))
dst.paste(imag1, (800, 1100))
dst.paste(imag2, (1000, 1100))

# %%
dst.paste(imag2,(200,1300))
dst.paste(imag1,(400,1300))
dst.paste(imag2, (600, 1300))
dst.paste(imag1, (800, 1300))
dst.paste(imag2, (1000, 1300))

# %%
plt.imshow(dst)

# %%
dst.save('cover_2.jpg', format='JPEG', quality=100)
